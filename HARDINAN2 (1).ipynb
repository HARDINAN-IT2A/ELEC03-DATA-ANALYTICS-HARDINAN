# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **DATASET INTO DATAFRAME**

# %%
UK = pd.read_csv('Data-set(UK)\\uk_road_accident.csv')

# %%
UK
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
UK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660654 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660653 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                656159 non-null  object
#  11  Urban_or_Rural_Area      660664 non-null  object
#  12  Weather_Conditions       646551 non-null  object
# ...

# %%
UK.describe().T
# Out:
#                          count       mean       std        min        25%  \
# Latitude              660654.0  52.553866  1.406922  49.914430  51.490690
# Longitude             660653.0  -1.431210  1.383330  -7.516225  -2.332291
# Number_of_Casualties  660679.0   1.357040  0.824847   1.000000   1.000000
# Number_of_Vehicles    660679.0   1.831255  0.715269   1.000000   1.000000
#
#                             50%        75%        max
# Latitude              52.315641  53.453452  60.757544
# Longitude             -1.411667  -0.232869   1.762010
# Number_of_Casualties   1.000000   1.000000  68.000000
# Number_of_Vehicles     2.000000   2.000000  32.000000

# %%
UK.isnull()
# Out:
#         Index  Accident_Severity  Accident Date  Latitude  Light_Conditions  \
# 0       False              False          False     False             False
# 1       False              False          False     False             False
# 2       False              False          False     False             False
# 3       False              False          False     False             False
# 4       False              False          False     False             False
# ...       ...                ...            ...       ...               ...
# 660674  False              False          False     False             False
# 660675  False              False          False     False             False
# 660676  False              False          False     False             False
# 660677  False              False          False     False             False
# 660678  False              False          False     False             False
#
# ...

# %%
UK.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                      25
# Light_Conditions               0
# District Area                  0
# Longitude                     26
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area           15
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %% [markdown]
# # **SELECTING THE COLUMNS**

# %%
UK['Accident_Severity']
# Out:
# 0         Serious
# 1         Serious
# 2         Serious
# 3         Serious
# 4          Slight
#            ...
# 660674     Slight
# 660675     Slight
# 660676     Slight
# 660677    Serious
# 660678    Serious
# Name: Accident_Severity, Length: 660679, dtype: object

# %%
UK['Accident_Severity'] == 'Serious'
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
#           ...
# 660674    False
# 660675    False
# 660676    False
# 660677     True
# 660678     True
# Name: Accident_Severity, Length: 660679, dtype: bool

# %%
UK['Accident Date']
# Out:
# 0           5/6/2019
# 1           2/7/2019
# 2         26-08-2019
# 3         16-08-2019
# 4           3/9/2019
#              ...
# 660674    18-02-2022
# 660675    21-02-2022
# 660676    23-02-2022
# 660677    23-02-2022
# 660678    28-02-2022
# Name: Accident Date, Length: 660679, dtype: object

# %%
UK['Accident Date'] == '26-08-2019'
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 660674    False
# 660675    False
# 660676    False
# 660677    False
# 660678    False
# Name: Accident Date, Length: 660679, dtype: bool

# %%
UK['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     563801
# Serious     88217
# Fatal        8661
# Name: count, dtype: int64

# %%
UK['Accident_Severity'].unique()
# Out:
# array(['Serious', 'Slight', 'Fatal'], dtype=object)

# %%
Fatal_df = UK[UK['Accident_Severity'] == 'Fatal']

# %%
Fatal_df
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 7       200701BS67370             Fatal     3/10/2019  51.482260
# 11      200701BS67747             Fatal     2/11/2019  51.499127
# 20      200701BS68301             Fatal    24-10-2019  51.505996
# 21      200701BS68302             Fatal    24-11-2019  51.486795
# 717     200701CP00032             Fatal    30-01-2019  51.510978
# ...               ...               ...           ...        ...
# 660470  201091NH00529             Fatal    29-01-2022  58.475726
# 660519  201091NJ01533             Fatal      2/2/2022  58.495554
# 660565  201091NJ11329             Fatal    15-08-2022  57.871514
# 660581  201091NJ14695             Fatal    21-10-2022  58.445475
# 660627  201091NL00060             Fatal      6/1/2022  60.241195
#
#              Light_Conditions           District Area  Longitude  \
# 7       Darkness - lights lit  Kensington and Chelsea  -0.179486
# ...

# %%
Serious_df = UK[UK['Accident_Severity'] == 'Serious']

# %%
Slight_df = UK[UK['Accident_Severity'] == 'Slight']

# %%
UK[UK['Latitude'] >= 50]
# Out:
#                 Index Accident_Severity Accident Date   Latitude  \
# 0       200701BS64157           Serious      5/6/2019  51.506187
# 1       200701BS65737           Serious      2/7/2019  51.495029
# 2       200701BS66127           Serious    26-08-2019  51.517715
# 3       200701BS66128           Serious    16-08-2019  51.495478
# 4       200701BS66837            Slight      3/9/2019  51.488576
# ...               ...               ...           ...        ...
# 660674  201091NM01760            Slight    18-02-2022  57.374005
# 660675  201091NM01881            Slight    21-02-2022  57.232273
# 660676  201091NM01935            Slight    23-02-2022  57.585044
# 660677  201091NM01964           Serious    23-02-2022  57.214898
# 660678  201091NM02142           Serious    28-02-2022  57.575210
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %%
UK[(UK['Accident_Severity'] == "Fatal") & (UK['Latitude'] >= 0)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8661 entries, 7 to 660627
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Index                    8661 non-null   object
#  1   Accident_Severity        8661 non-null   object
#  2   Accident Date            8661 non-null   object
#  3   Latitude                 8661 non-null   float64
#  4   Light_Conditions         8661 non-null   object
#  5   District Area            8661 non-null   object
#  6   Longitude                8661 non-null   float64
#  7   Number_of_Casualties     8661 non-null   int64
#  8   Number_of_Vehicles       8661 non-null   int64
#  9   Road_Surface_Conditions  8659 non-null   object
#  10  Road_Type                8628 non-null   object
#  11  Urban_or_Rural_Area      8661 non-null   object
#  12  Weather_Conditions       8554 non-null   object
#  13  Vehicle_Type             8661 non-null   object
# ...

# %% [markdown]
# # FILL UP NULL VALUES

# %%
UK.isnull().sum()
# Out:
# Index                          0
# Accident_Severity              0
# Accident Date                  0
# Latitude                       0
# Light_Conditions               0
# District Area                  0
# Longitude                      0
# Number_of_Casualties           0
# Number_of_Vehicles             0
# Road_Surface_Conditions      726
# Road_Type                   4520
# Urban_or_Rural_Area            0
# Weather_Conditions         14128
# Vehicle_Type                   0
# dtype: int64

# %%
UK['Latitude'].mean()
# Out:
# np.float64(52.553865761110956)

# %%
UK['Latitude'].fillna(UK['Latitude'].mean())
# Out:
# 0         51.506187
# 1         51.495029
# 2         51.517715
# 3         51.495478
# 4         51.488576
#             ...
# 660674    57.374005
# 660675    57.232273
# 660676    57.585044
# 660677    57.214898
# 660678    57.575210
# Name: Latitude, Length: 660679, dtype: float64

# %%
UK['Latitude'] = UK['Latitude'].fillna(UK['Latitude'].mean())
UK['Longitude'] = UK['Longitude'].fillna(UK['Longitude'].mean())
UK['Weather_Conditions'] = UK['Weather_Conditions'].fillna(UK['Weather_Conditions'].mode()[0])

# %%
UK.isnull().sum()
# Out:
# Index                         0
# Accident_Severity             0
# Accident Date                 0
# Latitude                      0
# Light_Conditions              0
# District Area                 0
# Longitude                     0
# Number_of_Casualties          0
# Number_of_Vehicles            0
# Road_Surface_Conditions     726
# Road_Type                  4520
# Urban_or_Rural_Area           0
# Weather_Conditions            0
# Vehicle_Type                  0
# dtype: int64

# %%
UK['Road_Type'] = UK['Accident Date'].fillna(UK['Road_Type'].mode()[0])

# %%
UK.isnull().sum()
# Out:
# Index                        0
# Accident_Severity            0
# Accident Date                0
# Latitude                     0
# Light_Conditions             0
# District Area                0
# Longitude                    0
# Number_of_Casualties         0
# Number_of_Vehicles           0
# Road_Surface_Conditions    726
# Road_Type                    0
# Urban_or_Rural_Area          0
# Weather_Conditions           0
# Vehicle_Type                 0
# dtype: int64

# %%
UK['Road_Type'].mode()
# Out:
# 0    30-11-2019
# Name: Road_Type, dtype: object

# %% [markdown]
# # CHANGE THE DATA TYPE OF A COLUMN

# %%
UK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  object
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660679 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660679 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                660679 non-null  object
#  11  Urban_or_Rural_Area      660679 non-null  object
#  12  Weather_Conditions       660679 non-null  object
# ...

# %%
UK['Accident_Severity'] = UK['Accident_Severity'].astype('category')

# %%
UK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  category
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660679 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660679 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                660679 non-null  object
#  11  Urban_or_Rural_Area      660679 non-null  object
#  12  Weather_Conditions       660679 non-null  object
# ...

# %%
UK.describe()
# Out:
#             Latitude      Longitude  Number_of_Casualties  Number_of_Vehicles
# count  660679.000000  660679.000000         660679.000000       660679.000000
# mean       52.553866      -1.431210              1.357040            1.831255
# std         1.406896       1.383302              0.824847            0.715269
# min        49.914430      -7.516225              1.000000            1.000000
# 25%        51.490696      -2.332191              1.000000            1.000000
# 50%        52.315755      -1.411761              1.000000            2.000000
# 75%        53.453444      -0.232901              1.000000            2.000000
# max        60.757544       1.762010             68.000000           32.000000

# %%
UK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660679 entries, 0 to 660678
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Index                    660679 non-null  object
#  1   Accident_Severity        660679 non-null  category
#  2   Accident Date            660679 non-null  object
#  3   Latitude                 660679 non-null  float64
#  4   Light_Conditions         660679 non-null  object
#  5   District Area            660679 non-null  object
#  6   Longitude                660679 non-null  float64
#  7   Number_of_Casualties     660679 non-null  int64
#  8   Number_of_Vehicles       660679 non-null  int64
#  9   Road_Surface_Conditions  659953 non-null  object
#  10  Road_Type                660679 non-null  object
#  11  Urban_or_Rural_Area      660679 non-null  object
#  12  Weather_Conditions       660679 non-null  object
# ...

# %%
UK.columns
# Out:
# Index(['Index', 'Accident_Severity', 'Accident Date', 'Latitude',
#        'Light_Conditions', 'District Area', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Road_Surface_Conditions',
#        'Road_Type', 'Urban_or_Rural_Area', 'Weather_Conditions',
#        'Vehicle_Type'],
#       dtype='object')

# %%
UK['Latitude'] = np.round(UK['Latitude'] / 1000, 1)

# %%
UK
# Out:
#                 Index Accident_Severity Accident Date  Latitude  \
# 0       200701BS64157           Serious      5/6/2019       0.1
# 1       200701BS65737           Serious      2/7/2019       0.1
# 2       200701BS66127           Serious    26-08-2019       0.1
# 3       200701BS66128           Serious    16-08-2019       0.1
# 4       200701BS66837            Slight      3/9/2019       0.1
# ...               ...               ...           ...       ...
# 660674  201091NM01760            Slight    18-02-2022       0.1
# 660675  201091NM01881            Slight    21-02-2022       0.1
# 660676  201091NM01935            Slight    23-02-2022       0.1
# 660677  201091NM01964           Serious    23-02-2022       0.1
# 660678  201091NM02142           Serious    28-02-2022       0.1
#
#                    Light_Conditions           District Area  Longitude  \
# 0             Darkness - lights lit  Kensington and Chelsea  -0.209082
# ...

# %% [markdown]
# # DATA AGGREFATION

# %%
PerArea = UK.groupby(['Accident_Severity','District Area']).count()

# %%
PerArea
# Out:
#                                  Index  Accident Date  Latitude  \
# Accident_Severity District Area
# Fatal             Aberdeen City     12             12        12
#                   Aberdeenshire     66             66        66
#                   Adur               8              8         8
#                   Allerdale         24             24        24
#                   Alnwick            6              6         6
# ...                                ...            ...       ...
# Slight            Wychavon        1138           1138      1138
#                   Wycombe         1493           1493      1493
#                   Wyre            1037           1037      1037
#                   Wyre Forest      815            815       815
#                   York            1621           1621      1621
#
#                                  Light_Conditions  Longitude  \
# Accident_Severity District Area
# Fatal             Aberdeen City                12         12
# ...

# %%
UK_insights = UK.groupby(['Accident_Severity','District Area','Urban_or_Rural_Area','Accident Date']).size()

# %%
UK_insights
# Out:
# Accident_Severity  District Area  Urban_or_Rural_Area  Accident Date
# Fatal              Aberdeen City  Rural                1/1/2019         0
#                                                        1/1/2020         0
#                                                        1/1/2021         0
#                                                        1/1/2022         0
#                                                        1/10/2019        0
#                                                                        ..
# Slight             York           Urban                9/8/2022         0
#                                                        9/9/2019         0
#                                                        9/9/2020         2
#                                                        9/9/2021         1
#                                                        9/9/2022         1
# Length: 5548878, dtype: int64

# %%
avg_Accident_Area = UK.groupby(['Accident_Severity','District Area'])['Number_of_Vehicles'].mean()

# %%
avg_Accident_Area
# Out:
# Accident_Severity  District Area
# Fatal              Aberdeen City    1.583333
#                    Aberdeenshire    1.712121
#                    Adur             1.500000
#                    Allerdale        1.750000
#                    Alnwick          2.166667
#                                       ...
# Slight             Wychavon         1.842707
#                    Wycombe          1.878768
#                    Wyre             1.887175
#                    Wyre Forest      1.792638
#                    York             1.870450
# Name: Number_of_Vehicles, Length: 1266, dtype: float64

# %% [markdown]
# # TESTING CORRELATION

# %%
latitude_cor = UK['Longitude'].corr(UK['Latitude'])

# %%
latitude_cor
# Out:
# np.float64(0.013194069604200285)

# %% [markdown]
# # Nemerical - Categorical Correlation Test

# %%
from scipy.stats import f_oneway

# %% [markdown]
# # **5 Insights from the First Look at the Dataset** (DATAFRAME)
#
# ## 1. **What do the first rows of the dataset show?**
# ###   *-The first few rows display information about different accidents, including severity, date, location, and vehicle details.*
#
# ## 2. **What kind of details are recorded?**
# ###  *-Each row has information such as accident severity, number of vehicles, number of casualties, weather, and road conditions.*
#
# ## 3. **Are there location details in the dataset?**
# ###  *-Yes, the dataset includes latitude and longitude for each accident, which means accidents can be mapped geographically.*
#
# ## 4. **Do the accident records show dates?**
# ###  *-Yes, the dataset includes an “Accident Date” column, showing when each accident happened.*
#
# ## 5. **Is vehicle information part of the data?**
# ###  *-Yes, there is a column called “Vehicle_Type” which shows the type of vehicle involved in the accidents.*

# %%
from scipy.stats import f_oneway
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 from scipy.stats import f_oneway
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# # 4 **Insights from the Dataset** (.info())
# ## 1. **How many rows are in the dataset?**
# ###  *-The dataset has 660,679 rows which means it records over six hundred thousand road accidents.*
#
# ## 2. **How many columns are included?**
# ###  *-There are 14 columns that describe details like accident severity, vehicles, casualties, weather, and so on.*
#
# ## 3. **What types of data are in the columns?**
# ###  *-Most of the columns are in object type (text), while only a few like Number_of_Casualties, Number_of_Vehicles, Latitude, and Longitude are numeric.*
#
# ## 4. **Are there any missing values?**
# ###  *-Yes, some columns have missing values, for example Weather_Conditions is missing a lot of data, and latitude/longitude are missing a few.*

# %% [markdown]
# # **3 Insights from the Summary Statistics** (.describe())
#
# ## 1. **What does the average number of casualties show?**
# ###  *-On average, there is about 1 casualty per accident, which means most accidents only involve a small number of people.*
#
# ## 2. **What about the number of vehicles per accident?**
# ###  *-The mean number of vehicles is around 1 to 2, showing that many accidents involve just one or two vehicles.*
#
# ## 3. **Do latitude and longitude values look consistent?**
# ###  *-Yes, the latitude and longitude ranges are close together without extreme outliers, meaning accident locations are recorded properly across the UK.*

# %% [markdown]
# # **6 Insights from Checking Missing Values** (.isnull())
#
# ## 1. **Does the dataset have any missing values overall?**
# ###  *-Yes, the dataset is not fully complete — some columns have missing information.*
#
# ## 2. **Which columns are almost complete?**
# ###  *-Columns like Accident_Severity, Accident Date, District Area, and Vehicle_Type have no missing values.*
#
# ## 3. **What about latitude and longitude?**
# ###  *-Latitude is missing 25 entries, and Longitude is missing 26 entries out of more than 660,000 — a very small amount compared to the whole dataset.*
#
# ## 4. **Which column has the largest number of missing values?**
# ###  *-Weather_Conditions has the most missing data, with over 14,000 entries left blank.*
#
# ## 5. **Are road details also missing in some cases?**
# ###  *-Yes, Road_Type and Road_Surface_Conditions have a few thousand missing records.*
#
# ## 6. **What does this mean for analysis?**
# ###  *-Most of the dataset is complete, but some analyses (like weather impact or road type studies) might need missing values to be filled or ignored.*

# %% [markdown]
# # **2 Insights from Accident Severity** (UK['Accident_Severity'])
#
# ## 1. **What does the Accident_Severity column contain?**
# ###  *-The column shows the level of each accident, such as Slight, Serious, or Fatal.*
#
# ## 2. **What happens when we check if Accident_Severity equals ‘Serious’?**
# ###  *-It gives a list of True/False values, where True means the accident was serious and False means it was not.*

# %% [markdown]
# # **3 Insights from Accident Date**
#
# ## 1. **What kind of data is in the Accident Date column?**
# ###  *-It contains the dates when each accident happened, written in day-month-year format.*
#
# ## 2. **Can we check for a specific date?**
# ###  *-Yes, by using a condition like UK['Accident Date'] == '26-08-2019', we can see which rows belong to that exact date.*
#
# ## 3. **What does the condition return?**
# ###  *-It gives a series of True/False values, where True means the accident happened on 26-08-2019 and False means it did not.*

# %% [markdown]
# # **3 Insights from Accident Severity Counts**
#
# ## 1. **Which type of accidents are the most common?**
# ###  *-The majority of accidents are labeled as **Slight**, making up the largest portion of the dataset.*
#
# ## 2. **How many serious accidents are there?**
# ###  *-There are thousands of accidents marked as **Serious**, showing that a significant number of cases are more severe than slight accidents.*
#
# ## 3. **Are fatal accidents common?**
# ###  *-Fatal accidents are the least common compared to Slight and Serious, but they are still an important part of the data for safety analysis.*

# %% [markdown]
# # **10 Insights from Accident Severity and Fatal Accidents**
#
# ## 1. **What are the unique accident severity levels?**
# ###  *-There are three categories: Slight, Serious, and Fatal.*
#
# ## 2. **Why is this important?**
# ###  *-It shows that all accidents in the dataset can be grouped into these three levels of severity.*
#
# ## 3. **What does Fatal_df contain?**
# ###  *-Fatal_df is a new dataset created by filtering only the accidents marked as Fatal.*
#
# ## 4. **How many rows are in Fatal_df?**
# ###  *-It contains only a small portion of the total accidents, since fatal cases are less frequent than others.*
#
# ## 5. **Do Fatal accidents have the same columns?**
# ###  *-Yes, Fatal_df still keeps all 14 columns, but only with rows where Accident_Severity = Fatal.*
#
# ## 6. **Why is filtering useful?**
# ###  *-Filtering allows us to focus only on the most serious type of accidents without mixing them with other data.*
#
# ## 7. **Can we compare Fatal accidents with others?**
# ###  *-Yes, by comparing Fatal_df with Serious or Slight accidents, we can study differences in conditions or causes.*
#
# ## 8. **Does Fatal_df also have missing values?**
# ###  *-Yes, it still has missing values in some columns like Weather_Conditions or Road_Type, just like the full dataset.*
#
# ## 9. **How can Fatal_df help analysis?**
# ###  *-It helps researchers and policymakers concentrate on the most dangerous accidents for better road safety planning.*
#
# ## 10. **What is the benefit of using unique() before filtering?**
# ###  *-By knowing the categories (Slight, Serious, Fatal), we can easily choose which one to filter, such as creating Fatal_df.*

# %% [markdown]
# # **5 Insights from Filtering Latitude and Fatal Accidents**
#
# ## 1. **What does Latitude >= 50 select?**
# ###  *-It keeps all accidents that happened in locations at latitude 50 or higher, which covers a big part of the UK.*
#
# ## 2. **What happens when we combine Latitude >= 50 with Fatal accidents?**
# ###  *-The filter shows only the most severe accidents (Fatal) that occurred in the same latitude range.*
#
# ## 3. **What does .info() tell us about this filtered data?**
# ###  *-It shows the number of rows that match the filter, along with the details of all 14 columns.*
#
# ## 4. **Does the filtered dataset still include missing values?**
# ###  *-Yes, even within this smaller set, some columns like Weather_Conditions or Road_Type can still have missing values.*
#
# ## 5. **Why is combining filters useful?**
# ###  *-By combining Accident Severity with Latitude, we can study where the most dangerous accidents happen in specific parts of the UK.*
